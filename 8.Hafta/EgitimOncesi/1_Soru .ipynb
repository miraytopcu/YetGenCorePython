# %% [markdown]
# # Problem 1
# ```test.txt``` dosyasındaki satır sayısını bularak ekrana yazdırınız.
#
#
#
# ```
# > Output
# Number of lines in the file:  6
#
# ```

# %%
#Sorunun Çözmünü Buraya Gerçekleştirebilirsiniz
# file_lengthy isimli bir fonksiyon oluşturup fname isimli parametre yollayalım.
def file_lengthy(fname):
    # with ile dosyamızı açalım ki iş bitince dosyanın tekrar kapanmasını sağlayalım
    with open(fname) as f:
        # for ile döngümüzü gezelim ve enumarate fonksiyonu ile her satırı numaralandıralım
        for i, l in enumerate(f):
            pass
    # i değerini 1 arttırıp return edelim
    return i + 1
# file_lengthy fonksiyonunu çağıralım ve sonucunu ekrana bastıralım
print("Number of lines in the file: ", file_lengthy("test.txt"))
# Out:
# Number of lines in the file:  8

# %%
import os

if not os.path.exists("test.txt"):
    with open("test.txt", "w", encoding="utf-8") as file:
        pass

with open("test.txt", "r", encoding="utf-8") as file:
    satir = file.readlines()
    satirSayisi = len(satir)
    print(satirSayisi)
# Out:
# 8

# %%
def count_line(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            lines = file.readlines()
            number_lines = len(lines)
            print("Number of lines in the line: ", number_lines)
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")

file_path = "test.txt"

count_line(file_path)
# Out:
# Number of lines in the line:  8
