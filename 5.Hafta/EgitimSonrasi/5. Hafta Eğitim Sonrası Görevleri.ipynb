# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
vi = float(input("ilk hiz: "))
a = float(input("ivme: "))
t = float(input("zaman: "))

def sonHiz(vi, a, t):
    global vf
    vf = vi + (a*t)
    print(vf)

sonHiz(vi, a, t)
# Out:
# 110.0

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
# 2.Problemin Çözümünü Buraya Yazınız
sayilar = []
for a in range(1,1001):
    sayilar.append(a)

def mukemmel(sayilar):
    global mukemmeller
    mukemmeller = []
    for i in sayilar:
        global toplam
        toplam = 0
        for x in range(1,i):
            if i % x == 0:
                toplam += x
            else:
                continue
        if toplam == i:
            mukemmeller.append(i)
    print(f"mukemmel sayilar: {mukemmeller}")

mukemmel(sayilar)
# Out:
# mukemmel sayilar: [6, 28, 496]

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
# 3.Problemin Çözümünü Buraya Yazınız
def pisagor():
    liste = []
    for a in range(1, 101):
        for b in range(a, 101):
            c_kare = a**2 + b**2
            c = int(c_kare**0.5)
            if c <= 100 and c_kare == c**2:
                liste.append((a, b, c))
    
    for ucgen in liste:
        print(f"Pisagor : {ucgen}")

pisagor()
# Out:
# Pisagor : (3, 4, 5)
# Pisagor : (5, 12, 13)
# Pisagor : (6, 8, 10)
# Pisagor : (7, 24, 25)
# Pisagor : (8, 15, 17)
# Pisagor : (9, 12, 15)
# Pisagor : (9, 40, 41)
# Pisagor : (10, 24, 26)
# Pisagor : (11, 60, 61)
# Pisagor : (12, 16, 20)
# Pisagor : (12, 35, 37)
# Pisagor : (13, 84, 85)
# Pisagor : (14, 48, 50)
# Pisagor : (15, 20, 25)
# Pisagor : (15, 36, 39)
# Pisagor : (16, 30, 34)
# Pisagor : (16, 63, 65)
# Pisagor : (18, 24, 30)
# Pisagor : (18, 80, 82)
# Pisagor : (20, 21, 29)
# Pisagor : (20, 48, 52)
# Pisagor : (21, 28, 35)
# Pisagor : (21, 72, 75)
# Pisagor : (24, 32, 40)
# Pisagor : (24, 45, 51)
# Pisagor : (24, 70, 74)
# Pisagor : (25, 60, 65)
# Pisagor : (27, 36, 45)
# Pisagor : (28, 45, 53)
# Pisagor : (28, 96, 100)
# Pisagor : (30, 40, 50)
# Pisagor : (30, 72, 78)
# Pisagor : (32, 60, 68)
# Pisagor : (33, 44, 55)
# Pisagor : (33, 56, 65)
# Pisagor : (35, 84, 91)
# Pisagor : (36, 48, 60)
# Pisagor : (36, 77, 85)
# Pisagor : (39, 52, 65)
# Pisagor : (39, 80, 89)
# Pisagor : (40, 42, 58)
# Pisagor : (40, 75, 85)
# Pisagor : (42, 56, 70)
# Pisagor : (45, 60, 75)
# Pisagor : (48, 55, 73)
# Pisagor : (48, 64, 80)
# Pisagor : (51, 68, 85)
# Pisagor : (54, 72, 90)
# Pisagor : (57, 76, 95)
# Pisagor : (60, 63, 87)
# Pisagor : (60, 80, 100)
# Pisagor : (65, 72, 97)

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
# 4.Problemin Çözümünü Buraya Yazınız
import math

kaplama = 5
yukseklik = int(input("yukseklik: "))
genislik = int(input("genislik: "))

def boyama(yukseklik, genislik):
    global kutu_sayisi
    kutu_sayisi = (yukseklik * genislik) / kaplama
    if type(kutu_sayisi) == float:
        kutu_sayisi = math.ceil(kutu_sayisi)
    print(kutu_sayisi)

boyama(yukseklik, genislik)
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
def sayac(kelime):
    kelime = kelime.lower()
    global unluHarf
    global unsuzHarf
    unluHarf = []
    unsuzHarf = []
    for i in kelime:
        if i.isalpha() == True:
            if i in ['a','e','ı','i','o','ö','u','ü']:
                if i in unluHarf :
                    continue
                else:
                    unluHarf.append(i)
            else:
                if i in unsuzHarf:
                    continue
                else:
                    unsuzHarf.append(i)
    print(f"unlu harfler : {unluHarf} \nunsuz harfler : {unsuzHarf}")

sayac("merhaba dünya!!hello")
# Out:
# unlu harfler : ['e', 'a', 'ü', 'o']
# unsuz harfler : ['m', 'r', 'h', 'b', 'd', 'n', 'y', 'l']

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
string = input("Enter integers using space: ")
given_list = string.split()  

def ciftBulma(given_list):
    index = 0
    while index < len(given_list):
        i = int(given_list[index])  
        if i % 2 == 1:
            given_list.pop(index)  
        else:
            index += 1  
    
    print(f"cift sayilar: {given_list}")

ciftBulma(given_list)
# Out:
# cift sayilar: ['2', '4', '6', '8']

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
# 7.Problemin Çözümünü Buraya Yazınız
