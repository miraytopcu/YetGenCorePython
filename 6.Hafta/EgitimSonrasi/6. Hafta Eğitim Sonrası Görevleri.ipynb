# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
liste = [2,4,6,7,8,9,10]
def ciftMi(x):
    if(x % 2 == 0):
        print(x)
    else:
        raise ValueError("tek sayı!!!")

list(map(ciftMi, liste))
# Out:
# 2
# 4
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       6     else:
#       7         raise ValueError("tek sayı!!!")
# ----> 9 list(map(ciftMi, liste))
#
# Cell In[1], line 7, in ciftMi(x)
#       5     print(x)
#       6 else:
# ----> 7     raise ValueError("tek sayı!!!")
#
# ValueError: tek sayı!!!

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import random
import time
hak = 5
print('''Oyunumuza Hoşgeldin!!!
      Bilgisayarımız 0 ile 100 arasında random bir sayı seçecek.
      Senden bu sayıyı tahmin etmeni istiyoruz.
      Toplam 5 hakkın bulunmaktadır.
      Tercihlerine göre seni yönlendireceğiz!
      Bol Şans!!!''')

bil_sayi = random.randint(1,100)
while hak > 0:
    tahmin = int(input("tahmininizi giriniz (çıkmak için q tuşlayınız): "))
    if(tahmin == 'q'):
        print("Çıkış yapılıyor...")
        break
    print(f"Tahmininiz: {tahmin}")
    time.sleep(1)
    if(tahmin == bil_sayi):
        print("Tebrikler! Tahmininiz doğru")
        break
    elif(tahmin > bil_sayi):
        print("Daha küçük bir sayi giriniz!")
        hak -= 1
    elif(tahmin < bil_sayi):
        print("Daha büyük bir sayi giriniz!")
        hak -= 1
    else:
        print("bir hata oluştu, lütfen tekrar deneyiniz!")
        break
if(hak == 0):
    print(f"Tahmin hakkınız bitmiştir! Doğru cevap: {bil_sayi}")
# Out:
# Oyunumuza Hoşgeldin!!!
#       Bilgisayarımız 0 ile 100 arasında random bir sayı seçecek.
#       Senden bu sayıyı tahmin etmeni istiyoruz.
#       Toplam 5 hakkın bulunmaktadır.
#       Tercihlerine göre seni yönlendireceğiz!
#       Bol Şans!!!
# Tahmininiz: 89
# Daha küçük bir sayi giriniz!
# Tahmininiz: 78
# Daha küçük bir sayi giriniz!
# Tahmininiz: 25
# Daha büyük bir sayi giriniz!
# Tahmininiz: 54
# Daha büyük bir sayi giriniz!
# Tahmininiz: 66
# Daha büyük bir sayi giriniz!
# Tahmin hakkınız bitmiştir! Doğru cevap: 74
