# %%
import random
import datetime

class musteri():
    def __init__(self,b):
        self.b = b
    
    def kriter():
        # input al, kişi sayısı, bütçe aralığı, lokasyan, tariler
        # ekstra hizmet: rehber ister mi
        return 2
    
    def otel():
        # oda / yatak sayısı, özel menü(vegan, laktozsuz, glutensiz vs), 
        return 3
    
    def ulasim():
        def from_to():
            # uzun yolu uçak, gemi, otobüs, şahsi araç
            return 6
        def mekan():
            # turistik mekanlara ulaşım: servis, toplu taşıma, şahsi araç
            return 7
        
    def fiyat_hesaplayici():
        # tercihler ve kampanya durumlarına göre fiyata ekleme çıkarma yapar 
        return 19
        
    def siralama():
        def en_cok_tercih_edilen():
            return 8
        def artan_fiyat():
            return 9
        def azalan_fiyat():
            return 10
        
    def odeme():
        def odeme_yontemi():
            # kredi kartı/ nakit/ havale
            return 11
        def odeme_yapma():
            return 18
        
    def kampanya():
        # random 2-3 tur paketine kampanya yap kullanıcı ona denk gelirse indirim
        return 12

    def kisi_kayit():
        # sisteme kişi kaydetme, dosyaya kaydedilip eğer dosyanın içinde zaten mevcutsa uyarı verilebilir
        return 14  

    def oncekiler():
        # daha önce aldığı paketler ve tarihlerini vs dosyada gösterir ve oraya ekler
        def ekle():
            return 15
        def goster():
            return 16
        
    def reminder():
        # satın alınan tarih için ne kadar süre kaldığını söyler
        return 17
        

class yurtici(musteri):
    def __init__(self,b,a):
        super().__init__(b)
        self.a = a
    
    def kategori():
        # karadeniz, kapadokya, gap, adalar vs
        return 1
    
    
    
class yurtdisi(musteri):
    def __init__(self,b,a):
        super().__init__(b)
        self.a = a

    def kategori():
        # balkan, italya, orta avrupa, büyük britanya, dubai vs
        return 4
    
    def ekstra_kriter():
        # kapıda vize/ vize gerektirmeyen
        return 5
    
    def dahil_olmayan_hizmetler():
        # yurt dışı çıkış haraç pulu, seyahat sağlık sigortası, vize ücretleri
        return 13
